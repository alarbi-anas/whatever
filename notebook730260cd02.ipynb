# %%
# !git clone https://github.com/tum-msv/mimo-cnn-est.git

# %%
# !python3 training_CNN_mimo.py

# %%
ls /kaggle/working/mimo-cnn-est/

# %%
ls

# %%
cd results

# %%
mkdir CNN_mimo

# %%
# !git push https://github.com/alarbi-anas/whatever.gitalarbi-anas
# Out:
# Username for 'https://github.com': ^C

# %%
# !zip -r whatever.zip /kaggle/working/mimo-cnn-est/results
# Out:
#   adding: kaggle/working/mimo-cnn-est/results/ (stored 0%)
#   adding: kaggle/working/mimo-cnn-est/results/CNN_mimo/ (stored 0%)
#   adding: kaggle/working/mimo-cnn-est/results/CNN_mimo/2022-05-14_22-45-31_3paths_64BS_antennas_2MS_antennas_35AS_2epochs_2ebatch_20lbatchsize_2pilots.csv (deflated 43%)

# %%
scp /kaggle/working/mimo-cnn-est/results/CNN_mimo/2022-05-14_22-45-31_3paths_64BS_antennas_2MS_antennas_35AS_2epochs_2ebatch_20lbatchsize_2pilots.csv root@86.107.197.21:/root/
